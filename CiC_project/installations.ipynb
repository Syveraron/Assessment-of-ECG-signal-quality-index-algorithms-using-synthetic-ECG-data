# %%
#link google drive

from google.colab import drive

drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %pwd
# %cd /content/drive/MyDrive/Colab_Notebooks/CiC_project
# !git clone https://github.com/LinusKra/ECGAssess.git

#changes to be made within the directories of files to work in colab:
#comment out the code in 'Algorithms_V5.py as algorithm cannot be used anymore (and not employed in code anywhere): 'from bigO import algorithm'
# Out:
# '/content'

# %%
# !git clone https://github.com/Kirina/Automated_ecg_assessment.git

#changes to be made within the directories of files to work in colab:
#in "Algorithms_V5_k_model.py" change 'data_preprocessing_utils import preprocess_dataset_toolbox, normalizer_minus_one_to_one' into: 'from cnn_lstm.utils.data_preprocessing_utils import preprocess_dataset_toolbox, normalizer_minus_one_to_one'
#in "data_processing_utils.py" change 'from parameters_gui import parameters_gui' into: 'from toolbox.parameters_gui import parameters_gui'

# %%
# !git clone https://github.com/kkarhin/framework_for_synthetic_biosignals.git
# Out:
# Cloning into 'framework_for_synthetic_biosignals'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 24 (delta 4), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (24/24), 2.12 MiB | 6.05 MiB/s, done.
# fatal: premature end of pack file, 55 bytes missing
# fatal: fetch-pack: invalid index-pack output
